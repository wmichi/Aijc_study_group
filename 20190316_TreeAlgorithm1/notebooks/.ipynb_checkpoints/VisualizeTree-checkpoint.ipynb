# %% [markdown]
# ## 木のサイズごとの可視化

# %%
# 親切な方が2019/2/19にGraphviz不要な可視化ライブラリを作ってくれた模様
# https://qiita.com/nekoumei/items/7f2209295515c3aa1053

# !pip install dtreeplt

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from dtreeplt import dtreeplt

# %%
# 目的変数が一番最初のカラムであることを確認
data = pd.read_csv('../data/basedata/train.csv')
data.head()

# %%
# 学習。一旦random_state以外の指定なし
model = DecisionTreeClassifier(random_state=0)
model.fit(data.iloc[:,1:], data.iloc[:,0])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# 可視化。ものすごく深く大きい木になっていることを確認
dtree = dtreeplt(
    model=model,
    feature_names=iris.feature_names,
    target_names=iris.target_names
)
fig = dtree.view()
# Out:
#    Survived      ...       Embarked_nan
# 0         0      ...                  0
# 1         1      ...                  0
# 2         1      ...                  0
# 3         1      ...                  0
# 4         0      ...                  0
#
# [5 rows x 30 columns]

# %%
# 今度は最大の深さを3にして学習
model = DecisionTreeClassifier(random_state=0, max_depth=3)
model.fit(data.iloc[:,1:], data.iloc[:,0])
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
# ...

# %%
# 今度は少し見やすい木になったもよぷ
dtree = dtreeplt(
    model=model,
    feature_names=data.columns.tolist()[1:],
    target_names='Survived'
)
fig = dtree.view()
# Out:
# ------------------------------------------------------
# NameError            Traceback (most recent call last)
# <ipython-input-21-f3cc008411e2> in <module>()
# ----> 1 dtree = dtreeplt(
#       2     model=model,
#       3     feature_names=data.columns.tolist()[1:],
#       4     target_names='Survived'
#       5 )
#
# NameError: name 'dtreeplt' is not defined
