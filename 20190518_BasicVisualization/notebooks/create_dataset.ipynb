# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# データの読み込み
df = pd.read_csv('../data/recipeData.csv')
df.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU  ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0  17.65  ...        1.038        70.0            NaN  Specific Gravity
# 1  60.65  ...        1.070        70.0            NaN  Specific Gravity
# 2  59.25  ...          NaN        70.0            NaN  Specific Gravity
# 3  54.48  ...          NaN        70.0            NaN  Specific Gravity
# 4  17.84  ...        1.050        72.0            NaN  Specific Gravity
#
#    BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0   All Grain        NaN       17.78    corn sugar          4.5 oz    116.0
# 1   All Grain        NaN         NaN           NaN             NaN    955.0
# 2     extract        NaN         NaN           NaN             NaN      NaN
# 3   All Grain        NaN         NaN           NaN             NaN      NaN
# 4   All Grain        NaN       19.00    Sukkerlake  6-7 g sukker/l  18325.0
#
# [5 rows x 23 columns]

# %%
# 取り扱い種類数の多い10スタイルに限定。
df.groupby(['Style'])['Style'].count()\
                     .reset_index(name='count')\
                     .sort_values(['count'], ascending=False)\
                     .reset_index(drop=True)\
                     .head(10)
# Out:
#                   Style  count
# 0          American IPA  11940
# 1     American Pale Ale   7581
# 2                Saison   2617
# 3  American Light Lager   2277
# 4    American Amber Ale   2038
# 5            Blonde Ale   1753
# 6          Imperial IPA   1478
# 7        American Stout   1268
# 8         Irish Red Ale   1204
# 9    American Brown Ale   1152

# %%
new_df = df.query('StyleID in (92, 6, 12, 86, 30, 4, 9, 134, 10, 7)')
new_df.head()
# Out:
#    BeerID                                      Name  \
# 2       3               Zombie Dust Clone - EXTRACT
# 3       4             Zombie Dust Clone - ALL GRAIN
# 5       6              Sierra Nevada Pale Ale Clone
# 6       7  Russian River Pliny the Elder (original)
# 9      10                        Mango Habanero IPA
#
#                                                  URL              Style  \
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...       American IPA
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...       American IPA
# 5  /homebrew/recipe/view/28546/sierra-nevada-pale...  American Pale Ale
# 6  /homebrew/recipe/view/37534/russian-river-plin...       Imperial IPA
# 9     /homebrew/recipe/view/61082/mango-habanero-ipa       Imperial IPA
#
#    StyleID  Size(L)     OG     FG   ABV     IBU  ...  BoilGravity  Efficiency  \
# 2        7    18.93  1.063  1.018  5.91   59.25  ...          NaN        70.0
# 3        7    22.71  1.061  1.017  5.80   54.48  ...          NaN        70.0
# 5       10    24.61  1.055  1.013  5.58   40.12  ...        1.047        79.0
# 6       86    22.71  1.072  1.018  7.09  268.71  ...          NaN        75.0
# 9       86    20.82  1.080  1.017  8.22   93.02  ...        1.058        70.0
#
#    MashThickness        SugarScale  BrewMethod  PitchRate PrimaryTemp  \
# 2            NaN  Specific Gravity     extract        NaN         NaN
# 3            NaN  Specific Gravity   All Grain        NaN         NaN
# 5            NaN  Specific Gravity   All Grain        1.0         NaN
# 6            NaN  Specific Gravity   All Grain        NaN         NaN
# 9            NaN  Specific Gravity   All Grain        NaN       21.11
#
#   PrimingMethod   PrimingAmount  UserId
# 2           NaN             NaN     NaN
# 3           NaN             NaN     NaN
# 5           NaN             NaN  5889.0
# 6           NaN             NaN  1051.0
# 9    Corn Sugar  4.6 oz / .66 C     NaN
#
# [5 rows x 23 columns]

# %%
new_df.Style.unique()
# Out:
# array(['American IPA', 'American Pale Ale', 'Imperial IPA', 'Saison',
#        'Blonde Ale', 'American Brown Ale', 'American Amber Ale',
#        'American Stout', 'Irish Red Ale', 'American Light Lager'],
#       dtype=object)

# %%
# 新しく振り直したIDリストを作成、出力
ids = pd.DataFrame(np.arange(1,11).reshape(-1,1))
new_df_ids = new_df[~new_df.duplicated(subset='Style', keep='first')].loc[:,['Style', 'StyleID']].reset_index()
new_df_ids = pd.concat([new_df_ids, ids], axis=1)
new_df_ids # 体裁整える前
# Out:
#    index                 Style  StyleID   0
# 0      2          American IPA        7   1
# 1      5     American Pale Ale       10   2
# 2      6          Imperial IPA       86   3
# 3     16                Saison      134   4
# 4     40            Blonde Ale       30   5
# 5     45    American Brown Ale        6   6
# 6     48    American Amber Ale        4   7
# 7     83        American Stout       12   8
# 8    122         Irish Red Ale       92   9
# 9    221  American Light Lager        9  10

# %%
new_df_ids = new_df_ids.iloc[:,[1,3]]
new_df_ids.columns = ['Style', 'class_ids']
new_df_ids.to_csv('../data/class_ids.csv',index=None)

# %%
beer_dict = {}
for i in range(10):
    style_name = new_df_ids.loc[i,'Style']
    style_id = new_df_ids.loc[i, 'class_ids']
    beer_dict[style_name] = style_id
    
beer_dict
# Out:
# {'American IPA': 1,
#  'American Pale Ale': 2,
#  'Imperial IPA': 3,
#  'Saison': 4,
#  'Blonde Ale': 5,
#  'American Brown Ale': 6,
#  'American Amber Ale': 7,
#  'American Stout': 8,
#  'Irish Red Ale': 9,
#  'American Light Lager': 10}

# %%
# 今回のモデリングに使用しないカラムを削除
USE_COLUMNS = ['Style', 'Size(L)', 'OG', 'FG',
       'ABV', 'IBU', 'Color', 'BoilSize', 'BoilTime', 'BoilGravity',
       'Efficiency', 'MashThickness', 'SugarScale', 'BrewMethod', 'PitchRate',
       'PrimaryTemp', 'PrimingMethod', 'PrimingAmount',]

new_df.loc[:,'Style'] = new_df.loc[:,'Style'].map(beer_dict)
new_df = new_df.loc[:, USE_COLUMNS]
new_df = new_df.rename(columns={'Style': 'class'})
new_df.head()
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#    class  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  BoilTime  \
# 2      1    18.93  1.063  1.018  5.91   59.25   8.98     22.71        60
# 3      1    22.71  1.061  1.017  5.80   54.48   8.50     26.50        60
# 5      2    24.61  1.055  1.013  5.58   40.12   8.00     29.34        70
# 6      3    22.71  1.072  1.018  7.09  268.71   6.33     30.28        90
# 9      3    20.82  1.080  1.017  8.22   93.02   8.29     28.39        60
#
#    BoilGravity  Efficiency  MashThickness        SugarScale BrewMethod  \
# 2          NaN        70.0            NaN  Specific Gravity    extract
# 3          NaN        70.0            NaN  Specific Gravity  All Grain
# 5        1.047        79.0            NaN  Specific Gravity  All Grain
# 6          NaN        75.0            NaN  Specific Gravity  All Grain
# 9        1.058        70.0            NaN  Specific Gravity  All Grain
#
#    PitchRate  PrimaryTemp PrimingMethod   PrimingAmount
# 2        NaN          NaN           NaN             NaN
# 3        NaN          NaN           NaN             NaN
# 5        1.0          NaN           NaN             NaN
# 6        NaN          NaN           NaN             NaN
# 9        NaN        21.11    Corn Sugar  4.6 oz / .66 C

# %%
df_train, df_test = train_test_split(new_df, test_size=0.2, random_state=0)
df_train.to_csv('../data/train.csv', index=None)
df_test.to_csv('../data/test.csv', index=None)
